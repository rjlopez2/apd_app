# %%
print("LAlal")
# Out:
# LAlal

# %%
import os
import pandas as pd
from glob import glob
import numpy as np
#import sys
#os.path.dirname(sys.executable)

# %% [markdown]
# Trying to read some files

# %%
root_dir = r"M:\Balazs\From Julien\Nico project"

# %%
file_dirs_list = glob(os.path.join(root_dir, "**", "*.csv"))
file_dirs_list
# Out:
# ['M:\\Balazs\\From Julien\\Nico project\\WT 6947\\30mmHg_raw data.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6947\\50mmHg_raw data.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6947\\75mmHg first_raw data.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6947\\75mmHg second_raw data.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6976\\6976 75mmHg  1st   RAWDATA.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6976\\6976_50mmHg RAWDATA.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6976\\6976_75mmHg RAWDATA.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6976\\6976_RAW_DATA 30mmHg.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6978\\6978 30mmHgRAWDATA.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6978\\6978 50mmHg RAWDATA.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6978\\6978_75mmHgrawdata.csv',
#  'M:\\Balazs\\From Julien\\Nico project\\WT 6979\\Raw data 6mmHg GSMx4.csv',
# ...

# %%
pd.read_csv(file_dirs_list[0])
# Out:
#             TIME     LVP       AP   CorFl  ECG_I  ECG_II  ECG_III  ECGaVR  \
# 0       4690.998  15.051  147.969  32.998  1.790   1.536   -0.252  -1.679
# 1       4690.999  14.848  147.969  32.886  1.995   1.703   -0.267  -1.766
# 2       4691.000  14.747  147.582  32.662  1.781   1.545   -0.257  -1.694
# 3       4691.001  14.747  147.679  32.662  1.452   1.163   -0.219  -1.211
# 4       4691.002  14.848  147.872  32.886  1.014   0.775   -0.205  -0.837
# ...          ...     ...      ...     ...    ...     ...      ...     ...
# 149564  4840.562  15.051  149.226  29.530 -1.029  -1.100    0.014   1.153
# 149565  4840.563  15.051  149.226  29.083 -1.405  -1.435    0.043   1.550
# 149566  4840.564  14.949  149.323  28.523 -1.810  -1.785    0.062   1.789
# 149567  4840.565  14.848  149.420  28.300 -1.781  -1.785    0.057   1.837
# 149568  4840.566  14.646  148.936  28.076 -1.671  -1.612    0.048   1.660
#
#         ECG_aVL  ECG_aVF   MAP1   MAP2   MAP3   MAP4   MAP5
# ...
